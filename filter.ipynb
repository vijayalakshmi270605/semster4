# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img=cv.imread('shiv.jpg')
plt.imshow(img),plt.title('SHIVAN')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
